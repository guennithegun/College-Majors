# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")

# %% [markdown]
# ### getting an overview for first row of the dataframe

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
shape_of_recent_grads = recent_grads.shape

# %%
raw_data_count = shape_of_recent_grads[0]

# %%
recent_grads = recent_grads.dropna()

# %%
new_shape = recent_grads.shape

# %%
cleaned_data_count = new_shape[0]

# %%
cleaned_data_count
# Out:
# 172

# %%
raw_data_count
# Out:
# 173

# %% [markdown]
# ### note
# there was one row with no values, which would have caused errors

# %% [markdown]
# ### scatter plots
# now exploring some relations

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', figsize=(16,9), xlim=(0,5000), ylim=(0,350000))

# %%
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter', figsize=(16,9))
ax.set_title('Median vs. Sample_size')
ax.set_xlim(0,5000)
# Out:
# (0, 5000)

# %%
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', figsize=(16,9))
ax.set_title('Unemployment Rate vs. Sample_size')
ax.set_xlim(0,5000)
ax.set_ylim(0, 0.2)
# Out:
# (0, 0.2)

# %%
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter', figsize=(16,9))
ax.set_title('Full_time vs. Median')
ax.set_xlim(0,300000)
# Out:
# (0, 300000)

# %%
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', figsize=(16,9))
ax.set_title('ShareWoman vs. Unemployment_rate')
ax.set_xlim(0, 1.2)
ax.set_ylim(0, 0.2)
# Out:
# (0, 0.2)

# %%
ax = recent_grads.plot(x='Men', y='Median', kind='scatter', figsize=(16,9))
ax.set_title('Men vs. Median')
ax.set_xlim(0,200000)
# Out:
# (0, 200000)

# %%
ax = recent_grads.plot(x='Women', y='Median', kind='scatter', figsize=(16,9))
ax.set_title('Women vs. Median')
ax.set_xlim(0,350000)
# Out:
# (0, 350000)

# %% [markdown]
# ### histograms
# exploring distridution

# %%
ax = recent_grads["Sample_size"].hist(bins=25, range=(0,5000))

# %%
ax = recent_grads["Median"].hist(bins=30, range=(0,120000), color="#47E5BC")

# %%
ax = recent_grads["Employed"].hist(bins=35, color="#FF6666")

# %%
ax = recent_grads["Full_time"].hist(bins=30, color="#5D2E8C")

# %%
ax = recent_grads["ShareWomen"].hist(bins=20, color="#F34213")

# %%
ax = recent_grads["Unemployment_rate"].hist(bins=15, range=(0,0.3), color="#136F63")

# %%
ax = recent_grads["Men"].hist(bins=25, color="#1789FC")

# %%
ax = recent_grads["Women"].hist(bins=25, color="#F26DF9")

# %%
rows_with_many_women = recent_grads[recent_grads["Women"] > 100000]

# %%
rows_with_many_women.loc[:,["Major","Women","ShareWomen","Total"]]
# Out:
#                                       Major     Women  ShareWomen     Total
# 34                                  NURSING  187621.0    0.896019  209394.0
# 40                               ACCOUNTING  104114.0    0.524153  198633.0
# 57                         GENERAL BUSINESS  102352.0    0.436302  234590.0
# 76   BUSINESS MANAGEMENT AND ADMINISTRATION  156118.0    0.473190  329927.0
# 77         MARKETING AND MARKETING RESEARCH  126354.0    0.615727  205211.0
# 93                           COMMUNICATIONS  143377.0    0.669999  213996.0
# 113                       GENERAL EDUCATION  116825.0    0.812877  143718.0
# 123                                 BIOLOGY  168947.0    0.601858  280709.0
# 137         ENGLISH LANGUAGE AND LITERATURE  136446.0    0.700898  194673.0
# 138                    ELEMENTARY EDUCATION  157833.0    0.923745  170862.0
# 145                              PSYCHOLOGY  307087.0    0.779933  393735.0

# %% [markdown]
# ### note
# because of the hight numbers in column "Women" i needed to find out which majors contain the highest numbers and what is the "ShareWomen".

# %% [markdown]
# ### median salary
# the most common median salary is inm the range of 32.000 to 36.000

# %% [markdown]
# ## scatter matrix
# exploring by scatter matrix

# %%
from pandas.plotting import scatter_matrix

# %%
ax = scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))

# %%
ax = scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))

# %% [markdown]
# ## bar plot
# now some bar plots

# %%
women_sorted = recent_grads.sort_values(by=["ShareWomen"], ascending=False)

# %%
ax = women_sorted[:10].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
ax = women_sorted[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
median_sorted = recent_grads.sort_values(by=["Median"], ascending=False)

# %%
ax = median_sorted[:10].plot.bar(x='Major', y='Median', legend=False)

# %%
ax = median_sorted[163:].plot.bar(x='Major', y='Median', legend=False)

# %%
unemployment_sorted = recent_grads.sort_values(by=["Unemployment_rate"], ascending=False)

# %%
ax = unemployment_sorted[163:].plot.bar(x='Major', y='Unemployment_rate', legend=False)
